# %%
#Part 2

nameList = ["Pete", "Tiffany", "Darius", "Jamal", "Anthony"]

#append a list by adding a name

nameList.append(["Julia", "Joey"])

#find and print length of the list

nameLength = len(nameList)

print(nameLength)

#slice a subsection of the 1st list and save it to a different 2nd list

newnameList = nameList[3:5] 

print(newnameList)

#extend your original list with the 2nd list sliced above ?

List2 = ["Joseph", "Sara"]

newnameList.extend(List2)

print(newnameList)



#BREAK#



#create a new list called simList 

simList = [5, 8, 27, 31, 983, 2, 13]

simList.sort()

print(simList)

#copy the simList to another third list

newsimList = simList.copy()

print(newsimList)

#add the second and third lists together into a fourth list

finalList = newnameList + newsimList

print(finalList)

#Part 3

tup1 = [24, 12, 36, 72, 60, 84]

tup2 = (tup1 * 3)

#access and print twelfth element

print(tup2[11])

#sort the second tuple and print

tup2.sort()

print(tup2)

#copy four specific elements from second tuple to third tupl

tup3 = tup2[4:8]

print(tup3)

#unpack tuple into four variables and print

(first, second, third, fourth) = tup3

print(first)
print(second)
print(third)
print(fourth)

#create a fourth tuple with single item 50 and print this tuple

tup4 = (50,)

print(tup4)


#add second and third tuple into fifth tuple

tup5 = (tup2 + tup3)

print(tup5)

#part 4 add a list of fruits to the above set and print the result


newSet = {'Card', 'Pencil', 'Tape'}

fruitList = ('Oranges', 'Bananas')

newSet.add(fruitList)


print("This is the new set with fruits:", newSet)


newSet.add('Ferrari')


oddSet = {'Computer', 'Water', 'Flashlight', 'Hat'}


#save the union of the first set and second set into a third set


unionSet = newSet.union(oddSet)


print("This is the combination of all the sets:\n", unionSet)


#pop an element from the second set and print the remainder of the set

oddSet.pop()

print(oddSet)

 
#clear the first set and print the result

newSet.clear()


#discard an element, and remove another from the third set

unionSet.discard('Bananas')

unionSet.remove('Card')


print(unionSet)



#Part 5

aDict = {
    'brand' : 'Nike',
    'year' : 1985,
    'person' : 'Michael Jordan',
    'points' : 23.5,
    'rookie' : True

}

print(aDict['brand'])

aDict.update({'person' : 'Pete Ancheta'})

print(aDict['person'])

aDict.update({'color' : 'green'})

aDict.update(dicTup = ('Water',))

x = aDict.keys()

print(x)

y = aDict.values()

print(y)

newDict = aDict.copy()

print(newDict)

newDict.update({'game' : 'madden'})

print(newDict)

newDict.clear()

print(newDict)
# Out:
# 6
# ['Jamal', 'Anthony']
# ['Jamal', 'Anthony', 'Joseph', 'Sara']
# [2, 5, 8, 13, 27, 31, 983]
# [2, 5, 8, 13, 27, 31, 983]
# ['Jamal', 'Anthony', 'Joseph', 'Sara', 2, 5, 8, 13, 27, 31, 983]
# 84
# [12, 12, 12, 24, 24, 24, 36, 36, 36, 60, 60, 60, 72, 72, 72, 84, 84, 84]
# [24, 24, 36, 36]
# 24
# 24
# 36
# 36
# (50,)
# [12, 12, 12, 24, 24, 24, 36, 36, 36, 60, 60, 60, 72, 72, 72, 84, 84, 84, 24, 24, 36, 36]
# This is the new set with fruits: {'Pencil', ('Oranges', 'Bananas'), 'Card', 'Tape'}
# This is the combination of all the sets:
#  {'Card', 'Flashlight', 'Hat', 'Ferrari', ('Oranges', 'Bananas'), 'Tape', 'Computer', 'Pencil', 'Water'}
# {'Water', 'Hat', 'Computer'}
# {'Flashlight', 'Hat', 'Ferrari', ('Oranges', 'Bananas'), 'Tape', 'Computer', 'Pencil', 'Water'}
# Nike
# Pete Ancheta
# dict_keys(['brand', 'year', 'person', 'points', 'rookie', 'color', 'dicTup'])
# dict_values(['Nike', 1985, 'Pete Ancheta', 23.5, True, 'green', ('Water',)])
# ...

# %%
newSet = {'Card', 'Pencil', 'Tape'}

fruitList = ('Oranges', 'Bananas')

newSet.add(fruitList)


print("This is the new set with fruits:", newSet)


newSet.add('Ferrari')
# Out:
# This is the new set with fruits: {'Pencil', ('Oranges', 'Bananas'), 'Card', 'Tape'}

# %%
simList = [5, 8, 27, 31, 983, 2, 13]

simList.sort()

print(simList)

#copy the simList to another third list

newsimList = simList.copy()

print(newsimList)

#add the second and third lists together into a fourth list

finalList = newnameList + newsimList

print(finalList)
# Out:
# [2, 5, 8, 13, 27, 31, 983]
# [2, 5, 8, 13, 27, 31, 983]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4248\3839217803.py in <module>
#      13 #add the second and third lists together into a fourth list
#      14
# ---> 15 finalList = newnameList + newsimList
#      16
#      17 print(finalList)
#
# NameError: name 'newnameList' is not defined
