# %%
age = 22

if age >= 25:
    print("Renting a car is more affordable")
else:
    print("Renting a car is very expensive")


if age >= 25:
    print("Renting a car is more affordable")
elif age < 25 and age >= 18:
    print("Renting a car is very expensive")
else: 
    print("You cannot legally rent a car")

#loop over the following string

phrase = 'The quick brown fox jumps over the lazy dog'

sum = 0
for char in phrase:
    sum += int(1)
print(sum)


num_vowels = 0
for char in phrase:
    if char in 'aeiouAEIOU':
        num_vowels = num_vowels+1
print(num_vowels)

couture_list = ['trousers', 'blouse', 'bandana', 
                'cumber band', 'blazer', 'vest',
                'french beret', 'scarf', 'stole']

panettone_set = ['cerise', 'fuschia', 'aqua',
                'maple', 'auburn', 'burnt sienna', 
                'gunmetal', 'blue', 'dark sapphire']


for x in couture_list:
    for y in panettone_set:
        print(y, x)

#use range as a loop to calculate the sum of all numbers from 1 to 100
#cannot figure this one out


#print the second item in this fruits list

fruits = ['apple', 'banana', 'cherry']
print(fruits[1])

#change the value from apple to kiwi

fruits[0] = 'kiwi'

print(fruits)

#use the append method to add orange to the fruits list

fruits.append('orange')

print(fruits)

#use the insert method to add lemon

fruits.insert(1, 'lemon')

print(fruits)

#use remove method to remove banan

fruits.remove('banana')

print(fruits)

#use negative indexing to print the 3rd and 2nd to last items in the list

print((fruits[-3]) , (fruits[-2]))

#use range of indexes to print third, fourth, and fifth item

print(fruits[1:4])

#print number of items in list

moreFruits = ["apple", "banana", "cherry", 
            "orange", "kiwi", "melon", "mango"]

size = len(moreFruits)

print(size)

#sort list in reverse order

moreFruits.sort(reverse=True)
print(moreFruits)
# Out:
# Renting a car is very expensive
# Renting a car is very expensive
# 43
# 11
# cerise trousers
# fuschia trousers
# aqua trousers
# maple trousers
# auburn trousers
# burnt sienna trousers
# gunmetal trousers
# blue trousers
# dark sapphire trousers
# cerise blouse
# fuschia blouse
# aqua blouse
# maple blouse
# auburn blouse
# burnt sienna blouse
# gunmetal blouse
# blue blouse
# dark sapphire blouse
# cerise bandana
# fuschia bandana
# aqua bandana
# maple bandana
# auburn bandana
# burnt sienna bandana
# gunmetal bandana
# blue bandana
# dark sapphire bandana
# cerise cumber band
# fuschia cumber band
# aqua cumber band
# maple cumber band
# auburn cumber band
# burnt sienna cumber band
# gunmetal cumber band
# blue cumber band
# dark sapphire cumber band
# cerise blazer
# fuschia blazer
# aqua blazer
# maple blazer
# auburn blazer
# burnt sienna blazer
# gunmetal blazer
# blue blazer
# dark sapphire blazer
# cerise vest
# fuschia vest
# aqua vest
# maple vest
# auburn vest
# ...
